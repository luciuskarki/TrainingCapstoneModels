# %%
import email
from phone_number.phone_number_code import is_a_phone_number
from ssn.ssn_code import is_a_ssn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[55], line 2
#       1 import email
# ----> 2 from phone_number.phone_number_code.ipynb import is_a_phone_number
#       3 from ssn.ssn_code import is_a_ssn
#
# ModuleNotFoundError: No module named 'phone_number.phone_number_code'

# %%
def get_file_contents(file):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")
    return content

# %%
def split_on_whitespace(pre_split_data):
    return pre_split_data.split()

# %%
file_path = 'words.txt'
file_contents = get_file_contents(file_path)
tokens = split_on_whitespace(file_contents)
for token in tokens:
    if ssn.is_a_ssn(token):
        print(token + " is a ssn")
    if phone_number.is_a_phone_number(token):
        print(token + " is a phone number")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 5
#       3 tokens = split_on_whitespace(file_contents)
#       4 for token in tokens:
# ----> 5     if ssn.is_a_ssn(token):
#       6         print(token + " is a ssn")
#       7     if phone_number.is_a_phone_number(token):
#
# AttributeError: module 'ssn' has no attribute 'is_a_ssn'
